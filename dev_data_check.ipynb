# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, regexp_extract, isnan, when, count, regexp_replace, split, concat_ws
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, ArrayType
import pydeequ
import sys
import os

# %%
def init_spark_session():
    spark = (SparkSession
        .builder
        .config("spark.jars.packages", pydeequ.deequ_maven_coord)
        .config("spark.jars.excludes", pydeequ.f2j_maven_coord)
        .getOrCreate())

    return spark

def read_file_from_args():
  print("Args: ", sys.argv[1:])
  filepath = ".\\data\\{}".format(sys.argv[1])
  return filepath


def data_cleaning(df_init):
  df_init

# %% [markdown]
# ### Define Schema

# %%
schema = StructType([ \
    StructField("url", StringType(), True),
    StructField("address", StringType(), True),
    StructField("name", StringType(), False),
    StructField("rate", StringType(), True),
    StructField("votes", IntegerType(), True),
    StructField("phone", IntegerType(), False),
    StructField("location", StringType(), False),
    StructField("rest_type", StringType(), True),
    StructField("dish_liked", ArrayType(StringType()), True),
    StructField("cuisines", StringType(), True),
    StructField("reviews_list", ArrayType(StringType()), True)
])

# %%
if __name__ == "__main__":
  
  print("Setting up spark and variables...")
  spark = init_spark_session()

  csv_filepath= read_file_from_args()

  df = spark.read \
          .option("header", True) \
          .option("delimiter",",") \
      .csv("data/data_file_20210527182730.csv")
# Out:
# Setting up spark and variables...
# Args:  ['-f', 'C:\\Users\\9837340\\AppData\\Roaming\\jupyter\\runtime\\kernel-22689fcf-2eec-46f5-8f4b-7345e1d81fd4.json']

# %%
df.toPandas()
# Out:
#                                                     2url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1                                        +91 9743772233"
# 2      https://www.zomato.com/bangalore/spice-elephan...
# 3      https://www.zomato.com/SanchurroBangalore?cont...
# 4      https://www.zomato/bangalore/addhuri-udupi-bho...
# ...                                                  ...
# 10284  https://www.zomato.com/bangalore/oakleaf-white...
# 10285                                     +91 725959971"
# 10286  https://www.zomato.com/bangalore/kidilum-white...
# 10287                                     +91 890486998"
# 10288  https://www.zomato.com/bangalore/mad-over-donu...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1                                           Banashankari
# 2      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 3      1112, Next to KIMS Medical College, 17th Cross...
# 4      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# ...                                                  ...
# 10284  62, Forum Neighbourhood Mall, Whitefield, Bang...
# 10285                                         Whitefield
# 10286  125/5, Behind ITPL, Pattandur Agrahara, Whitef...
# 10287                                         Whitefield
# 10288  K-F02, 1st Floor, Ascendas Park Square Mall, W...
#
#                         name  \
# 0                      Jalsa
# 1              Casual Dining
# 2             Spice Elephant
# 3            San Churro Cafe
# 4      Addhuri Udupi Bhojana
# ...                      ...
# 10284                Oakleaf
# 10285          Casual Dining
# 10286                Kidilum
# 10287            Quick Bites
# 10288        Mad Over Donuts
#
#                                             online_order  \
# 0                                                    Yes
# 1      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 2                                                    Yes
# 3                                                    Yes
# 4                                                     No
# ...                                                  ...
# 10284                                                Yes
# 10285                                             Salmon
# 10286                                                Yes
# 10287  Beef Fry, Appam, Chicken Curry, Kerala Parotta...
# 10288                                                Yes
#
#                                       book_table   rate  \
# 0                                            Yes  4.1/5
# 1                 North Indian, Mughlai, Chinese    800
# 2                                             No  4.1/5
# 3                                             No  3.8/5
# 4                                             No  3.7/5
# ...                                          ...    ...
# 10284                                         No  3.9/5
# 10285  Asian, Continental, North Indian, Italian  2,000
# 10286                                         No  3.8/5
# 10287              Kerala, Chinese, North Indian    350
# 10288                                         No  3.7/5
#
#                                                    votes  \
# 0                                                    775
# 1      "[('Rated 4.0', 'RATED\n  A beautiful place to...
# 2                                                    787
# 3                                                    918
# 4                                                     88
# ...                                                  ...
# 10284                                                 40
# 10285  [('Rated 5.0', 'RATED\n  Stayed at Oakwood Res...
# 10286                                                207
# 10287  [('Rated 4.0', 'RATED\n  Ordered morning break...
# 10288                                                 28
#
#                                                    phone  \
# 0                                           080 42297555
# 1                                           ('Rated 4.0'
# 2                                           080 41714161
# 3                                          +91 966348799
# 4                                         +91 9620009302
# ...                                                  ...
# 10284                                       080 66708888
# 10285  ['Cheese Stuffed Paratha', 'Crunchy Panko Coat...
# 10286                                     +91 9845041750
# 10287  ['Egg Roast', 'Chicken Curry', 'Chicken Roast'...
# 10288                                     +91 8067266398
#
#                                                 location            rest_type  \
# 0                                                   None                 None
# 1       'RATED\n  You canÃ\x83Ã\x83Ã\x82Ã\x82Ã\x...         ('Rated 5.0'
# 2                                           Banashankari        Casual Dining
# 3                                           Banashankari  Cafe, Casual Dining
# 4                                           Banashankari          Quick Bites
# ...                                                  ...                  ...
# 10284                                               None                 None
# 10285                                           Delivery          Brookefield
# 10286                                               None                 None
# 10287                                           Delivery          Brookefield
# 10288                                         Whitefield       Dessert Parlor
#
#                                               dish_liked  \
# 0                                                   None
# 1       'RATED\n  Overdelighted by the service and fo...
# 2      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 3      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 4                                            Masala Dosa
# ...                                                  ...
# 10284                                               None
# 10285                                               None
# 10286                                               None
# 10287                                               None
# 10288                                               None
#
#                           cuisines  \
# 0                             None
# 1                     ('Rated 4.0'
# 2      Chinese, North Indian, Thai
# 3           Cafe, Mexican, Italian
# 4       South Indian, North Indian
# ...                            ...
# 10284                         None
# 10285                         None
# 10286                         None
# 10287                         None
# 10288  Bakery, Desserts, Beverages
#
#                              approx_cost(for two people)  \
# 0                                                   None
# 1       'RATED\n  The place is nice and comfortable. ...
# 2                                                    800
# 3                                                    800
# 4                                                    300
# ...                                                  ...
# 10284                                               None
# 10285                                               None
# 10286                                               None
# 10287                                               None
# 10288                                                450
#
#                                             reviews_list  \
# 0                                                   None
# 1                                           ('Rated 4.0'
# 2      "[('Rated 4.0', 'RATED\n  Had been here for di...
# 3      "[('Rated 3.0', ""RATED\n  Ambience is not tha...
# 4      "[('Rated 4.0', ""RATED\n  Great food and prop...
# ...                                                  ...
# 10284                                               None
# 10285                                               None
# 10286                                               None
# 10287                                               None
# 10288  "[('Rated 4.0', 'RATED\n  A small outlet in th...
#
#                                                menu_item  \
# 0                                                   None
# 1       'RATED\n  The place is nice and comfortable. ...
# 2      rice was well cooked and overall was great\n\n...
# 3                                           ('Rated 3.0'
# 4                                           ('Rated 2.0'
# ...                                                  ...
# 10284                                               None
# 10285                                               None
# 10286                                               None
# 10287                                               None
# 10288  if they'd wish to have a small budget dessert!...
#
#                                          listed_in(type)  \
# 0                                                   None
# 1                                           ('Rated 4.0'
# 2                                           ('Rated 5.0'
# 3       ""RATED\n \nWent there for a quick bite with ...
# 4       'RATED\n  Reached the place at 3pm on Saturda...
# ...                                                  ...
# 10284                                               None
# 10285                                               None
# 10286                                               None
# 10287                                               None
# 10288                                       ('Rated 3.0'
#
#                                          listed_in(city)
# 0                                                   None
# 1       'RATED\n  The place is nice and comfortable. ...
# 2       'RATED\n  This place just cool ? with good am...
# 3       pasta churros and lasagne.\n\nNachos were pat...
# 4                                           ('Rated 4.0'
# ...                                                  ...
# 10284                                               None
# 10285                                               None
# 10286                                               None
# 10287                                               None
# 10288   ""RATED\n  Ordered chocolate marble waffle. T...
#
# [10289 rows x 17 columns]

# %% [markdown]
# ### Dropping unused columns

# %%
df_drop_columns = df.drop('online_order', 'book_table', 'approx_cost(for two people)', 'menu_item', 'listed_in(type)', 'listed_in(city)')
df_drop_columns.printSchema()
# Out:
# root
#  |-- 2url: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- rate: string (nullable = true)
#  |-- votes: string (nullable = true)
#  |-- phone: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- rest_type: string (nullable = true)
#  |-- dish_liked: string (nullable = true)
#  |-- cuisines: string (nullable = true)
#  |-- reviews_list: string (nullable = true)

# %%
df_column_castted = df_drop_columns.withColumn("dish_liked_array", split(col('dish_liked'), ',')) \
                        .withColumn("review_list_array", split(col('reviews_list'), ',')) \
                        .withColumn("cuisines_array", split(col("cuisines"), ',')) \
                        .drop("dish_liked", "reviews_list", "cuisines")
df_column_castted.printSchema()
# Out:
# root
#  |-- 2url: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- rate: string (nullable = true)
#  |-- votes: string (nullable = true)
#  |-- phone: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- rest_type: string (nullable = true)
#  |-- dish_liked_array: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- review_list_array: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- cuisines_array: array (nullable = true)
#  |    |-- element: string (containsNull = false)

# %%
df_column_castted.toPandas()
# Out:
#                                                     2url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1                                        +91 9743772233"
# 2      https://www.zomato.com/bangalore/spice-elephan...
# 3      https://www.zomato.com/SanchurroBangalore?cont...
# 4      https://www.zomato/bangalore/addhuri-udupi-bho...
# ...                                                  ...
# 10284  https://www.zomato.com/bangalore/oakleaf-white...
# 10285                                     +91 725959971"
# 10286  https://www.zomato.com/bangalore/kidilum-white...
# 10287                                     +91 890486998"
# 10288  https://www.zomato.com/bangalore/mad-over-donu...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1                                           Banashankari
# 2      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 3      1112, Next to KIMS Medical College, 17th Cross...
# 4      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# ...                                                  ...
# 10284  62, Forum Neighbourhood Mall, Whitefield, Bang...
# 10285                                         Whitefield
# 10286  125/5, Behind ITPL, Pattandur Agrahara, Whitef...
# 10287                                         Whitefield
# 10288  K-F02, 1st Floor, Ascendas Park Square Mall, W...
#
#                         name   rate  \
# 0                      Jalsa  4.1/5
# 1              Casual Dining    800
# 2             Spice Elephant  4.1/5
# 3            San Churro Cafe  3.8/5
# 4      Addhuri Udupi Bhojana  3.7/5
# ...                      ...    ...
# 10284                Oakleaf  3.9/5
# 10285          Casual Dining  2,000
# 10286                Kidilum  3.8/5
# 10287            Quick Bites    350
# 10288        Mad Over Donuts  3.7/5
#
#                                                    votes  \
# 0                                                    775
# 1      "[('Rated 4.0', 'RATED\n  A beautiful place to...
# 2                                                    787
# 3                                                    918
# 4                                                     88
# ...                                                  ...
# 10284                                                 40
# 10285  [('Rated 5.0', 'RATED\n  Stayed at Oakwood Res...
# 10286                                                207
# 10287  [('Rated 4.0', 'RATED\n  Ordered morning break...
# 10288                                                 28
#
#                                                    phone  \
# 0                                           080 42297555
# 1                                           ('Rated 4.0'
# 2                                           080 41714161
# 3                                          +91 966348799
# 4                                         +91 9620009302
# ...                                                  ...
# 10284                                       080 66708888
# 10285  ['Cheese Stuffed Paratha', 'Crunchy Panko Coat...
# 10286                                     +91 9845041750
# 10287  ['Egg Roast', 'Chicken Curry', 'Chicken Roast'...
# 10288                                     +91 8067266398
#
#                                                 location            rest_type  \
# 0                                                   None                 None
# 1       'RATED\n  You canÃ\x83Ã\x83Ã\x82Ã\x82Ã\x...         ('Rated 5.0'
# 2                                           Banashankari        Casual Dining
# 3                                           Banashankari  Cafe, Casual Dining
# 4                                           Banashankari          Quick Bites
# ...                                                  ...                  ...
# 10284                                               None                 None
# 10285                                           Delivery          Brookefield
# 10286                                               None                 None
# 10287                                           Delivery          Brookefield
# 10288                                         Whitefield       Dessert Parlor
#
#                                         dish_liked_array  \
# 0                                                   None
# 1      [ 'RATED\n  Overdelighted by the service and f...
# 2      [Momos,  Lunch Buffet,  Chocolate Nirvana,  Th...
# 3      [Churros,  Cannelloni,  Minestrone Soup,  Hot ...
# 4                                          [Masala Dosa]
# ...                                                  ...
# 10284                                               None
# 10285                                               None
# 10286                                               None
# 10287                                               None
# 10288                                               None
#
#                                        review_list_array  \
# 0                                                   None
# 1                                        [ ('Rated 4.0']
# 2      ["[('Rated 4.0',  'RATED\n  Had been here for ...
# 3      ["[('Rated 3.0',  ""RATED\n  Ambience is not t...
# 4      ["[('Rated 4.0',  ""RATED\n  Great food and pr...
# ...                                                  ...
# 10284                                               None
# 10285                                               None
# 10286                                               None
# 10287                                               None
# 10288  ["[('Rated 4.0',  'RATED\n  A small outlet in ...
#
#                         cuisines_array
# 0                                 None
# 1                      [ ('Rated 4.0']
# 2      [Chinese,  North Indian,  Thai]
# 3           [Cafe,  Mexican,  Italian]
# 4        [South Indian,  North Indian]
# ...                                ...
# 10284                             None
# 10285                             None
# 10286                             None
# 10287                             None
# 10288  [Bakery,  Desserts,  Beverages]
#
# [10289 rows x 11 columns]

# %% [markdown]
# ## Data Exploration

# %%
df.select('rest_type').distinct().show()
# Out:
# +--------------------+
# |           rest_type|
# +--------------------+
# | I tried blue lim...|
# | he said ' This i...|
# | chicken ghee roa...|
# | very reasonably ...|
# |Beverage Shop, De...|
# | thought of givin...|
# | received re frie...|
# |['New Chicken Mah...|
# |               Dhaba|
# | this is the plac...|
# | place order agai...|
# |              Bakery|
# | ""RATED\n  Since...|
# | Chicken tikka ma...|
# | not bad at all. ...|
# | as well as Iced ...|
# |                 Bar|
# | have tried their...|
# |        'Raagi Roti'|
# | but with excelle...|
# +--------------------+
# only showing top 20 rows

# %%
df_regex_url = df_column_castted.withColumn("valid_url", regexp_extract(col('2url'), r"[(http(s)?):\/\/(www\.)?a-zA-Z0-9@:%._\+~#=]{2,256}\.[a-z]{2,6}\b([-a-zA-Z0-9@:%_\+.~#?&//=]*)", 0))
df_regex_columns = df_regex_url.withColumn("phone_valid", regexp_replace( regexp_extract(col('phone'), r"\d[\d -]{8,12}\d", 0), " ", ''))
df_regex_columns.select('2url', 'valid_url', 'phone', 'phone_valid').toPandas()
# Out:
#                                                     2url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1                                        +91 9743772233"
# 2      https://www.zomato.com/bangalore/spice-elephan...
# 3      https://www.zomato.com/SanchurroBangalore?cont...
# 4      https://www.zomato/bangalore/addhuri-udupi-bho...
# ...                                                  ...
# 10284  https://www.zomato.com/bangalore/oakleaf-white...
# 10285                                     +91 725959971"
# 10286  https://www.zomato.com/bangalore/kidilum-white...
# 10287                                     +91 890486998"
# 10288  https://www.zomato.com/bangalore/mad-over-donu...
#
#                                                valid_url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1
# 2      https://www.zomato.com/bangalore/spice-elephan...
# 3      https://www.zomato.com/SanchurroBangalore?cont...
# 4      https://www.zomato/bangalore/addhuri-udupi-bho...
# ...                                                  ...
# 10284  https://www.zomato.com/bangalore/oakleaf-white...
# 10285
# 10286  https://www.zomato.com/bangalore/kidilum-white...
# 10287
# 10288  https://www.zomato.com/bangalore/mad-over-donu...
#
#                                                    phone   phone_valid
# 0                                           080 42297555   08042297555
# 1                                           ('Rated 4.0'
# 2                                           080 41714161   08041714161
# 3                                          +91 966348799   91966348799
# 4                                         +91 9620009302  919620009302
# ...                                                  ...           ...
# 10284                                       080 66708888   08066708888
# 10285  ['Cheese Stuffed Paratha', 'Crunchy Panko Coat...
# 10286                                     +91 9845041750  919845041750
# 10287  ['Egg Roast', 'Chicken Curry', 'Chicken Roast'...
# 10288                                     +91 8067266398  918067266398
#
# [10289 rows x 4 columns]

# %%
df_regex_columns_v2 = df_regex_columns.withColumn("valid_votes", regexp_extract(col('votes'), r"^[0-9]*$", 0))
df_regex_columns_v2.select('votes', 'valid_votes').toPandas()
# Out:
#                                                    votes valid_votes
# 0                                                    775         775
# 1      "[('Rated 4.0', 'RATED\n  A beautiful place to...
# 2                                                    787         787
# 3                                                    918         918
# 4                                                     88          88
# ...                                                  ...         ...
# 10284                                                 40          40
# 10285  [('Rated 5.0', 'RATED\n  Stayed at Oakwood Res...
# 10286                                                207         207
# 10287  [('Rated 4.0', 'RATED\n  Ordered morning break...
# 10288                                                 28          28
#
# [10289 rows x 2 columns]

# %%
df_replace_comma_address = df_regex_columns_v2.withColumn("address_cleaned", regexp_replace(regexp_extract(col('address'), r"^[#.0-9a-zA-Z\s,-]+$", 0), ',', "")) \
                                            .withColumn("rate_valid", regexp_extract(col('rate'), r"(\d+\.?\d+)\/(\d*\.?\d*)",0))
df_replace_comma_address.select('address', 'address_cleaned', 'rate', 'rate_valid').toPandas()
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1                                           Banashankari
# 2      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 3      1112, Next to KIMS Medical College, 17th Cross...
# 4      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# ...                                                  ...
# 10284  62, Forum Neighbourhood Mall, Whitefield, Bang...
# 10285                                         Whitefield
# 10286  125/5, Behind ITPL, Pattandur Agrahara, Whitef...
# 10287                                         Whitefield
# 10288  K-F02, 1st Floor, Ascendas Park Square Mall, W...
#
#                                          address_cleaned   rate rate_valid
# 0      942 21st Main Road 2nd Stage Banashankari Bang...  4.1/5      4.1/5
# 1                                           Banashankari    800
# 2      2nd Floor 80 Feet Road Near Big Bazaar 6th Blo...  4.1/5      4.1/5
# 3      1112 Next to KIMS Medical College 17th Cross 2...  3.8/5      3.8/5
# 4      1st Floor Annakuteera 3rd Stage Banashankari B...  3.7/5      3.7/5
# ...                                                  ...    ...        ...
# 10284   62 Forum Neighbourhood Mall Whitefield Bangalore  3.9/5      3.9/5
# 10285                                         Whitefield  2,000
# 10286                                                     3.8/5      3.8/5
# 10287                                         Whitefield    350
# 10288  K-F02 1st Floor Ascendas Park Square Mall Whit...  3.7/5      3.7/5
#
# [10289 rows x 4 columns]

# %% [markdown]
# #### Location dataset lookup and validation

# %%
df_location = spark.read \
          .option("inferSchema",True) \
          .option("header", True) \
          .option("delimiter",",") \
      .csv("data/Areas_in_blore.csv")

# %%
df_location.printSchema()
# Out:
# root
#  |-- Area: string (nullable = true)
#  |-- Taluk: string (nullable = true)
#  |-- District: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Pincode: integer (nullable = true)

# %%
df_location.toPandas()
# Out:
#                       Area            Taluk   District      State  Pincode
# 0    A F Station Yelahanka  Bangalore North  Bangalore  KARNATAKA   560063
# 1                    Agram  Bangalore South  Bangalore  KARNATAKA   560007
# 2       Air Force Hospital  Bangalore North  Bangalore  KARNATAKA   560007
# 3             Amruthahalli  Bangalore North  Bangalore  KARNATAKA   560092
# 4     Anandnagar Bangalore  Bangalore North  Bangalore  KARNATAKA   560024
# ..                     ...              ...        ...        ...      ...
# 259   Tavarekere Bangalore   Bangaloresouth  Bangalore  KARNATAKA   562130
# 260    Thammanayakanahalli           Anekal  Bangalore  KARNATAKA   562106
# 261          Vanakanahalli           Anekal  Bangalore  KARNATAKA   562106
# 262            Vidyanagara         Bg North  Bangalore  KARNATAKA   562157
# 263          Yadavanahalli           Anekal  Bangalore  KARNATAKA   562107
#
# [264 rows x 5 columns]

# %% [markdown]
# ### LEFT JOIN df with df_location
# #### To see which df row is valid for location

# %%
df_join_location = df_replace_comma_address.join(df_location, df_replace_comma_address['location'] == df_location['Area'], "left")

# %%
print(df_join_location.filter(col("Area").isNotNull()).count())
# Out:
# 2246

# %%
df_join_location.filter(col("Area").isNotNull()).toPandas()
# Out:
#                                                    2url  \
# 0     https://www.zomato.com/bangalore/spice-elephan...
# 1     https://www.zomato.com/SanchurroBangalore?cont...
# 2     https://www.zomato/bangalore/addhuri-udupi-bho...
# 3     https://www.zomato.com/bangalore/cafe-shuffle-...
# 4     https://www.zomato.com/bangalore/the-coffee-sh...
# ...                                                 ...
# 2241  https://www.zomato.com/bangalore/bangalore-aga...
# 2242  https://www.zomato.com/bangalore/mangalore-lun...
# 2243  https://www.zomato.com/bangalore/desi-doze-whi...
# 2244  https://www.zomato.com/bangalore/hunger-stop-w...
# 2245  https://www.zomato.com/bangalore/mad-over-donu...
#
#                                                 address  \
# 0     2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 1     1112, Next to KIMS Medical College, 17th Cross...
# 2     1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 3     941, 3rd FLOOR, 21st Main, 22nd Cross, Banasha...
# 4         6th Block, 3rd Stage, Banashankari, Bangalore
# ...                                                 ...
# 2241  47, Bangalore Agarwal Bhavan, Pattandur Agraha...
# 2242  SJR Teck Park, Plot 13, 14, 15, EpIp Area, Whi...
# 2243  1, Nallurhalli Road, Opposite Brigade RV Cente...
# 2244  Opposite to Neeladari Apartment,Nallurahalli R...
# 2245  K-F02, 1st Floor, Ascendas Park Square Mall, W...
#
#                           name   rate votes           phone      location  \
# 0               Spice Elephant  4.1/5   787    080 41714161  Banashankari
# 1              San Churro Cafe  3.8/5   918   +91 966348799  Banashankari
# 2        Addhuri Udupi Bhojana  3.7/5    88  +91 9620009302  Banashankari
# 3                 Cafe Shuffle  4.2/5   150   +91 974216677  Banashankari
# 4             The Coffee Shack  4.2/5   164   +91 973164421  Banashankari
# ...                        ...    ...   ...             ...           ...
# 2241  Bangalore Agarwal Bhavan  3.3/5     6  +91 8310009071    Whitefield
# 2242      Mangalore Lunch Home  3.4/5     8  +91 9448426577    Whitefield
# 2243                 Desi Doze  3.8/5   147  +91 9742425962    Whitefield
# 2244               Hunger Stop  3.7/5   100  +91 7829999672    Whitefield
# 2245           Mad Over Donuts  3.7/5    28  +91 8067266398    Whitefield
#
#                 rest_type                                   dish_liked_array  \
# 0           Casual Dining  [Momos,  Lunch Buffet,  Chocolate Nirvana,  Th...
# 1     Cafe, Casual Dining  [Churros,  Cannelloni,  Minestrone Soup,  Hot ...
# 2             Quick Bites                                      [Masala Dosa]
# 3                    Cafe  [Mocktails,  Peri Fries,  Lasagne,  Pizza,  Ch...
# 4                    Cafe  [Coffee,  Spaghetti,  Pancakes,  Nachos,  Past...
# ...                   ...                                                ...
# 2241           Sweet Shop                                               None
# 2242          Quick Bites                                               None
# 2243          Quick Bites  [Lassi,  Paratha,  Chaach,  Chole Bhature,  Th...
# 2244          Quick Bites                                               None
# 2245       Dessert Parlor                                               None
#
#                                       review_list_array  ...  \
# 0     ["[('Rated 4.0',  'RATED\n  Had been here for ...  ...
# 1     ["[('Rated 3.0',  ""RATED\n  Ambience is not t...  ...
# 2     ["[('Rated 4.0',  ""RATED\n  Great food and pr...  ...
# 3     ["[('Rated 1.0',  ""RATED\n \n\nHorrible. Not ...  ...
# 4     ["[('Rated 4.0',  ""RATED\n  Food - 4/5\nAmbie...  ...
# ...                                                 ...  ...
# 2241  [[('Rated 1.0',  'RATED\n  Had ordered food on...  ...
# 2242  ["[('Rated 4.0',  'RATED\n  I ordered neer dos...  ...
# 2243  ["[('Rated 1.0',  'RATED\n  Dal was completely...  ...
# 2244  ["[('Rated 3.0',  ""RATED\n  Actual 3.5(since ...  ...
# 2245  ["[('Rated 4.0',  'RATED\n  A small outlet in ...  ...
#
#                                               valid_url   phone_valid  \
# 0     https://www.zomato.com/bangalore/spice-elephan...   08041714161
# 1     https://www.zomato.com/SanchurroBangalore?cont...   91966348799
# 2     https://www.zomato/bangalore/addhuri-udupi-bho...  919620009302
# 3     https://www.zomato.com/bangalore/cafe-shuffle-...   91974216677
# 4     https://www.zomato.com/bangalore/the-coffee-sh...   91973164421
# ...                                                 ...           ...
# 2241  https://www.zomato.com/bangalore/bangalore-aga...  918310009071
# 2242  https://www.zomato.com/bangalore/mangalore-lun...  919448426577
# 2243  https://www.zomato.com/bangalore/desi-doze-whi...  919742425962
# 2244  https://www.zomato.com/bangalore/hunger-stop-w...  917829999672
# 2245  https://www.zomato.com/bangalore/mad-over-donu...  918067266398
#
#      valid_votes                                    address_cleaned  \
# 0            787  2nd Floor 80 Feet Road Near Big Bazaar 6th Blo...
# 1            918  1112 Next to KIMS Medical College 17th Cross 2...
# 2             88  1st Floor Annakuteera 3rd Stage Banashankari B...
# 3            150  941 3rd FLOOR 21st Main 22nd Cross Banashankar...
# 4            164         6th Block 3rd Stage Banashankari Bangalore
# ...          ...                                                ...
# 2241           6  47 Bangalore Agarwal Bhavan Pattandur Agrahara...
# 2242           8  SJR Teck Park Plot 13 14 15 EpIp Area Whitefie...
# 2243         147  1 Nallurhalli Road Opposite Brigade RV Center ...
# 2244         100  Opposite to Neeladari ApartmentNallurahalli Ro...
# 2245          28  K-F02 1st Floor Ascendas Park Square Mall Whit...
#
#      rate_valid          Area            Taluk   District      State Pincode
# 0         4.1/5  Banashankari  Bangalore South  Bangalore  KARNATAKA  560050
# 1         3.8/5  Banashankari  Bangalore South  Bangalore  KARNATAKA  560050
# 2         3.7/5  Banashankari  Bangalore South  Bangalore  KARNATAKA  560050
# 3         4.2/5  Banashankari  Bangalore South  Bangalore  KARNATAKA  560050
# 4         4.2/5  Banashankari  Bangalore South  Bangalore  KARNATAKA  560050
# ...         ...           ...              ...        ...        ...     ...
# 2241      3.3/5    Whitefield  Bangalore South  Bangalore  KARNATAKA  560066
# 2242      3.4/5    Whitefield  Bangalore South  Bangalore  KARNATAKA  560066
# 2243      3.8/5    Whitefield  Bangalore South  Bangalore  KARNATAKA  560066
# 2244      3.7/5    Whitefield  Bangalore South  Bangalore  KARNATAKA  560066
# 2245      3.7/5    Whitefield  Bangalore South  Bangalore  KARNATAKA  560066
#
# [2246 rows x 21 columns]

# %%
df_valid_location = df_join_location.filter(col("Area").isNotNull())

# %%
df_nulls_filtered = df_valid_location.filter( (col('name').isNotNull()  
                                               & col('phone').isNotNull() 
                                               & col('location').isNotNull()) )
df_nulls_filtered.count()
# Out:
# 2246

# %%
df_nulls_filtered.printSchema()
# Out:
# root
#  |-- 2url: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- rate: string (nullable = true)
#  |-- votes: string (nullable = true)
#  |-- phone: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- rest_type: string (nullable = true)
#  |-- dish_liked_array: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- review_list_array: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- cuisines_array: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- valid_url: string (nullable = true)
#  |-- phone_valid: string (nullable = true)
#  |-- valid_votes: string (nullable = true)
#  |-- address_cleaned: string (nullable = true)
#  |-- rate_valid: string (nullable = true)
#  |-- Area: string (nullable = true)
#  |-- Taluk: string (nullable = true)
#  |-- District: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Pincode: integer (nullable = true)

# %%
df_drop_unused_columns = df_nulls_filtered.drop('2url', 'address', 'phone', 'votes', 'rate', 'Area', 'Taluk', 'District', 'State', 'Pincode')
df_renamed_columns = df_drop_unused_columns.withColumnRenamed('valid_url','url') \
                                        .withColumnRenamed('address_cleaned', 'address') \
                                        .withColumnRenamed('phone_valid', 'phone') \
                                        .withColumnRenamed('valid_votes', 'votes') \
                                        .withColumnRenamed('rate_valid', 'rate')

df_renamed_columns.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- rest_type: string (nullable = true)
#  |-- dish_liked_array: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- review_list_array: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- cuisines_array: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- url: string (nullable = true)
#  |-- phone: string (nullable = true)
#  |-- votes: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- rate: string (nullable = true)

# %% [markdown]
# #### As CSV doesn't support array types we need to convert them to String type.
# ##### Here is a example of how I'm going to convert array type columns to string

# %%
df_renamed_columns.withColumn('dish_liked', concat_ws(' ', col('dish_liked_array'))).select('dish_liked').toPandas()
# Out:
#                                              dish_liked
# 0     Momos  Lunch Buffet  Chocolate Nirvana  Thai G...
# 1     Churros  Cannelloni  Minestrone Soup  Hot Choc...
# 2                                           Masala Dosa
# 3     Mocktails  Peri Fries  Lasagne  Pizza  Chicken...
# 4     Coffee  Spaghetti  Pancakes  Nachos  Pasta  Sa...
# ...                                                 ...
# 2241
# 2242
# 2243       Lassi  Paratha  Chaach  Chole Bhature  Thali
# 2244
# 2245
#
# [2246 rows x 1 columns]

# %%
df_arrays_to_string = df_renamed_columns.withColumn('dish_liked', concat_ws(' ', col('dish_liked_array'))) \
                                    .withColumn('review_list', concat_ws(' ', col('review_list_array'))) \
                                    .withColumn('cuisines', concat_ws(' ', col('cuisines_array'))) \
                                .drop('dish_liked_array', 'review_list_array', 'cuisines_array')

# %%
df_arrays_to_string.select('dish_liked', 'review_list', 'cuisines').toPandas()
# Out:
#                                              dish_liked  \
# 0     Momos  Lunch Buffet  Chocolate Nirvana  Thai G...
# 1     Churros  Cannelloni  Minestrone Soup  Hot Choc...
# 2                                           Masala Dosa
# 3     Mocktails  Peri Fries  Lasagne  Pizza  Chicken...
# 4     Coffee  Spaghetti  Pancakes  Nachos  Pasta  Sa...
# ...                                                 ...
# 2241
# 2242
# 2243       Lassi  Paratha  Chaach  Chole Bhature  Thali
# 2244
# 2245
#
#                                             review_list  \
# 0     "[('Rated 4.0'  'RATED\n  Had been here for di...
# 1     "[('Rated 3.0'  ""RATED\n  Ambience is not tha...
# 2     "[('Rated 4.0'  ""RATED\n  Great food and prop...
# 3     "[('Rated 1.0'  ""RATED\n \n\nHorrible. Not ev...
# 4     "[('Rated 4.0'  ""RATED\n  Food - 4/5\nAmbienc...
# ...                                                 ...
# 2241  [('Rated 1.0'  'RATED\n  Had ordered food onli...
# 2242  "[('Rated 4.0'  'RATED\n  I ordered neer dosa ...
# 2243  "[('Rated 1.0'  'RATED\n  Dal was completely b...
# 2244  "[('Rated 3.0'  ""RATED\n  Actual 3.5(since we...
# 2245  "[('Rated 4.0'  'RATED\n  A small outlet in th...
#
#                                      cuisines
# 0                 Chinese  North Indian  Thai
# 1                      Cafe  Mexican  Italian
# 2                  South Indian  North Indian
# 3                  Cafe  Italian  Continental
# 4         Cafe  Chinese  Continental  Italian
# ...                                       ...
# 2241                      Mithai  Street Food
# 2242  North Indian  South Indian  Mangalorean
# 2243                  North Indian  Fast Food
# 2244         North Indian  Chinese  Fast Food
# 2245              Bakery  Desserts  Beverages
#
# [2246 rows x 3 columns]

# %% [markdown]
# #### Cleaning review_list from unwanted special chars/ junk chars

# %%
df_special_char_cleaned = df_arrays_to_string.withColumn('review_list', regexp_replace(col('review_list'), "[^a-zA-Z0-9]", " ")) \
                                            .withColumn("phone", df_arrays_to_string.phone.cast('integer')) \
                                            .withColumn("votes", df_arrays_to_string.votes.cast('integer'))

# %% [markdown]
# #### Sorting column as the output expected

# %%
df_columns_sorted = df_special_char_cleaned.select(col('url'),
                                             col('address'),
                                             col('name'),
                                             col('rate'),
                                             col('votes'),
                                             col('phone'),
                                             col('location'),
                                             col('rest_type'),
                                             col('dish_liked'),
                                             col('cuisines'),
                                             col('review_list'))
df_columns_sorted.printSchema()
# Out:
# root
#  |-- url: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- rate: string (nullable = true)
#  |-- votes: integer (nullable = true)
#  |-- phone: integer (nullable = true)
#  |-- location: string (nullable = true)
#  |-- rest_type: string (nullable = true)
#  |-- dish_liked: string (nullable = false)
#  |-- cuisines: string (nullable = false)
#  |-- review_list: string (nullable = false)

# %% [markdown]
# ### Writting Valid output data (mostly)

# %%
df_columns_sorted.toPandas().to_csv("./output/record_out.csv", index=False)

# %% [markdown]
# #### As we can see, joining the main data with area data is going to tell us which register is going to be valid for us (at least to be valid for this test). So as we got valid data only with the join of this two dataframes, now those how doesn't have a valid location are going to be grouped as _**bad data**_

# %% [markdown]
# #### For bad data or data that doesn't meet the requirements are going to be writed as **_'record_bad.csv'_**

# %% [markdown]
# #### As we can see there is a lot of error in this new dataset.

# %%
df_join_location.filter(col('Area').isNull()).toPandas()
# Out:
#                                                    2url  \
# 0     https://www.zomato.com/bangalore/jalsa-banasha...
# 1                                       +91 9743772233"
# 2     https://www.zomato.com/bangalore/grand-village...
# 3                                        +91 990121000"
# 4     https://www.zomato/bangalore/timepass-dinner-b...
# ...                                                 ...
# 8038  https://www.zomato.com/bangalore/south-house-b...
# 8039  https://www.zomato.com/bangalore/oakleaf-white...
# 8040                                     +91 725959971"
# 8041  https://www.zomato.com/bangalore/kidilum-white...
# 8042                                     +91 890486998"
#
#                                                 address             name  \
# 0     942, 21st Main Road, 2nd Stage, Banashankari, ...            Jalsa
# 1                                          Banashankari    Casual Dining
# 2     10, 3rd Floor, Lakshmi Associates, Gandhi Baza...    Grand Village
# 3                                          Basavanagudi    Casual Dining
# 4     37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...  Timepass Dinner
# ...                                                 ...              ...
# 8038  579, Ground Floor, C Block AECS Layout, Kundal...      South House
# 8039  62, Forum Neighbourhood Mall, Whitefield, Bang...          Oakleaf
# 8040                                         Whitefield    Casual Dining
# 8041  125/5, Behind ITPL, Pattandur Agrahara, Whitef...          Kidilum
# 8042                                         Whitefield      Quick Bites
#
#        rate                                              votes  \
# 0     4.1/5                                                775
# 1       800  "[('Rated 4.0', 'RATED\n  A beautiful place to...
# 2     3.8/5                                                166
# 3       600  [('Rated 4.0', 'RATED\n  Very good restaurant ...
# 4     3.8/5                                                286
# ...     ...                                                ...
# 8038  3.8/5                                                 97
# 8039  3.9/5                                                 40
# 8040  2,000  [('Rated 5.0', 'RATED\n  Stayed at Oakwood Res...
# 8041  3.8/5                                                207
# 8042    350  [('Rated 4.0', 'RATED\n  Ordered morning break...
#
#                                                   phone  \
# 0                                          080 42297555
# 1                                          ('Rated 4.0'
# 2                                        +91 8026612447
# 3                                                    []
# 4                                        +91 9980040002
# ...                                                 ...
# 8038                                      +91 960627999
# 8039                                       080 66708888
# 8040  ['Cheese Stuffed Paratha', 'Crunchy Panko Coat...
# 8041                                     +91 9845041750
# 8042  ['Egg Roast', 'Chicken Curry', 'Chicken Roast'...
#
#                                                location      rest_type  \
# 0                                                  None           None
# 1      'RATED\n  You canÃ\x83Ã\x83Ã\x82Ã\x82Ã\x...   ('Rated 5.0'
# 2                                                  None           None
# 3                                                Buffet   Banashankari
# 4                                                  None           None
# ...                                                 ...            ...
# 8038                                        Brookefield  Casual Dining
# 8039                                               None           None
# 8040                                           Delivery    Brookefield
# 8041                                               None           None
# 8042                                           Delivery    Brookefield
#
#                                        dish_liked_array  \
# 0                                                  None
# 1     [ 'RATED\n  Overdelighted by the service and f...
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 8038  [Egg Biryani,  Roti,  Mutton Biryani,  Chicken...
# 8039                                               None
# 8040                                               None
# 8041                                               None
# 8042                                               None
#
#                                       review_list_array  ...  \
# 0                                                  None  ...
# 1                                       [ ('Rated 4.0']  ...
# 2                                                  None  ...
# 3                                                  None  ...
# 4                                                  None  ...
# ...                                                 ...  ...
# 8038  ["[('Rated 3.0',  'RATED\n  Ordered Egg Biryan...  ...
# 8039                                               None  ...
# 8040                                               None  ...
# 8041                                               None  ...
# 8042                                               None  ...
#
#                                               valid_url   phone_valid  \
# 0     https://www.zomato.com/bangalore/jalsa-banasha...   08042297555
# 1
# 2     https://www.zomato.com/bangalore/grand-village...  918026612447
# 3
# 4     https://www.zomato/bangalore/timepass-dinner-b...  919980040002
# ...                                                 ...           ...
# 8038  https://www.zomato.com/bangalore/south-house-b...   91960627999
# 8039  https://www.zomato.com/bangalore/oakleaf-white...   08066708888
# 8040
# 8041  https://www.zomato.com/bangalore/kidilum-white...  919845041750
# 8042
#
#      valid_votes                                    address_cleaned  \
# 0            775  942 21st Main Road 2nd Stage Banashankari Bang...
# 1                                                      Banashankari
# 2            166  10 3rd Floor Lakshmi Associates Gandhi Bazaar ...
# 3                                                      Basavanagudi
# 4            286  37 5-1 4th Floor Bosco Court Gandhi Bazaar Mai...
# ...          ...                                                ...
# 8038          97  579 Ground Floor C Block AECS Layout Kundalaha...
# 8039          40   62 Forum Neighbourhood Mall Whitefield Bangalore
# 8040                                                     Whitefield
# 8041         207
# 8042                                                     Whitefield
#
#      rate_valid  Area Taluk District State Pincode
# 0         4.1/5  None  None     None  None     NaN
# 1                None  None     None  None     NaN
# 2         3.8/5  None  None     None  None     NaN
# 3                None  None     None  None     NaN
# 4         3.8/5  None  None     None  None     NaN
# ...         ...   ...   ...      ...   ...     ...
# 8038      3.8/5  None  None     None  None     NaN
# 8039      3.9/5  None  None     None  None     NaN
# 8040             None  None     None  None     NaN
# 8041      3.8/5  None  None     None  None     NaN
# 8042             None  None     None  None     NaN
#
# [8043 rows x 21 columns]

# %%
df_bad_data = df_join_location.filter(col('Area').isNull()) \
                              .withColumn('dish_liked', concat_ws(' ', col('dish_liked_array'))) \
                              .withColumn('review_list', concat_ws(' ', col('review_list_array'))) \
                              .withColumn('cuisines', concat_ws(' ', col('cuisines_array'))) \
                            .drop('2url', 'address', 'phone', 'votes', 'rate', 'Area', 'Taluk', 'District', 'State', 'Pincode','dish_liked_array', 'review_list_array', 'cuisines_array') \
                            .withColumnRenamed('valid_url','url') \
                            .withColumnRenamed('address_cleaned', 'address') \
                            .withColumnRenamed('phone_valid', 'phone') \
                            .withColumnRenamed('valid_votes', 'votes') \
                            .withColumnRenamed('rate_valid', 'rate') \
                        .select(col('url'),
                                col('address'),
                                col('name'),
                                col('rate'),
                                col('votes'),
                                col('phone'),
                                col('location'),
                                col('rest_type'),
                                col('dish_liked'),
                                col('cuisines'),
                                col('review_list'))

# %%
df_bad_data.printSchema()
# Out:
# root
#  |-- url: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- rate: string (nullable = true)
#  |-- votes: string (nullable = true)
#  |-- phone: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- rest_type: string (nullable = true)
#  |-- dish_liked: string (nullable = false)
#  |-- cuisines: string (nullable = false)
#  |-- review_list: string (nullable = false)

# %% [markdown]
# ### Writing bad data as CSV file

# %%
df_bad_data.toPandas().to_csv("./output/record_bad.csv", index=False)

# %% [markdown]
# ### Data Validation

# %% [markdown]
# ##### * Votes column:

# %%
from pydeequ.checks import *
from pydeequ.verification import *

check = Check(spark, CheckLevel.Warning, "Review Check")

checkResult_votes_column = VerificationSuite(spark) \
    .onData(df_columns_sorted) \
    .addCheck(
        #Votes
        check.isNonNegative("votes") \
        .hasDataType("votes", ConstrainableDataTypes.Numeric) \
        .isComplete("votes")
        .hasMin("votes", lambda x: x >= 0)
        #Phone
        .hasDataType("phone", ConstrainableDataTypes.Numeric) \
        .isComplete("phone") \
        .isNonNegative("phone") \
        #Location
        .hasDataType("location", ConstrainableDataTypes.String) \
        .isComplete("location") \
        #Name
        .hasDataType("name", ConstrainableDataTypes.String) \
        .isComplete("name")
    
        ) \
    .run()

checkResult_df = VerificationResult.checkResultsAsDataFrame(spark, checkResult_votes_column)
checkResult_df.show(truncate=True)
# Out:
# +------------+-----------+------------+--------------------+-----------------+--------------------+
# |       check|check_level|check_status|          constraint|constraint_status|  constraint_message|
# +------------+-----------+------------+--------------------+-----------------+--------------------+
# |Review Check|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# |Review Check|    Warning|     Warning|AnalysisBasedCons...|          Success|                    |
# |Review Check|    Warning|     Warning|CompletenessConst...|          Success|                    |
# |Review Check|    Warning|     Warning|MinimumConstraint...|          Success|                    |
# |Review Check|    Warning|     Warning|AnalysisBasedCons...|          Success|                    |
# |Review Check|    Warning|     Warning|CompletenessConst...|          Failure|Value: 0.10863757...|
# |Review Check|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# |Review Check|    Warning|     Warning|AnalysisBasedCons...|          Success|                    |
# |Review Check|    Warning|     Warning|CompletenessConst...|          Success|                    |
# |Review Check|    Warning|     Warning|AnalysisBasedCons...|          Success|                    |
# |Review Check|    Warning|     Warning|CompletenessConst...|          Success|                    |
# +------------+-----------+------------+--------------------+-----------------+--------------------+

# %% [markdown]
# ##### As above shows us, we can use Pydeequ framework to analyze and check data validations on Spark
